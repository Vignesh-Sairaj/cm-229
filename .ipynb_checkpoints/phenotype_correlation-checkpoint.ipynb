# %%
import os
import sys
import pandas as pd 
import numpy as np
from data_import import *

# %%
# import data
geno_df, pheno_df = import_data_islets()
# Out:
# Samples:
# ...

# %%
# calculate correlation
corr_mat = pheno_df.corr()

# %%
high_cor = corr_mat[(corr_mat.abs() > 0.5) & (corr_mat.abs() < 1)].dropna(how = "all")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(20, 20))

heatmap = sns.heatmap(high_cor, ax = ax)
heatmap.figure

# %%
long = high_cor.stack().rename_axis(["Trait_1", "Trait_2"]).reset_index(name = "value")
long
# Out:
#                    Trait_1                     Trait_2     value
# 0              weight_12wk                  weight_3wk  0.706187
# 1              weight_12wk                  weight_4wk  0.706187
# 2              weight_12wk                  weight_5wk  0.706188
# 3              weight_12wk                  weight_6wk  0.706185
# 4              weight_12wk                  weight_7wk  0.706185
# 5              weight_12wk                  weight_8wk  0.706186
# 6              weight_12wk                  weight_9wk  0.706187
# 7              weight_12wk                 weight_10wk  0.706188
# 8              weight_12wk                 weight_14wk  0.629974
# 9              weight_12wk                 weight_15wk  0.531024
# 10             weight_12wk                 wtchg_wk3v1  0.706186
# 11             weight_12wk                 wtchg_wk4v1  0.706186
# 12             weight_12wk                 wtchg_wk5v1  0.706188
# ...

# %%
heatmap = sb.heatmap(long)
heatmap.figure
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-d6a0c853ffc0> in <module>()
#       1 long = high_cor.stack().rename_axis(["Trait_1", "Trait_2"]).reset_index(name = "value")
#       2 long
# ----> 3 heatmap = sb.heatmap(long)
#       4 heatmap.figure
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     515     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     516                           annot_kws, cbar, cbar_kws, xticklabels,
# --> 517                           yticklabels, mask)
#     518
#     519     # Add the pcolormesh kwargs here
#
# ...

# %%
corr_mat.shape
# Out:
# (154, 154)
